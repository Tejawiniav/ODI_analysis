# %%
import pandas as pd
import numpy as np
import datetime as dt

# %%
x=pd.read_csv(r'D:\Tejaswini\odi-batting.csv')
x.head(5)
# Out:
#        Country            Player   Runs  ScoreRate  MatchDate  \
# 0  Afghanistan  Mohammad Shahzad  118.0      97.52  2-16-2010
# 1  Afghanistan  Mohammad Shahzad  110.0      99.09   9-1-2009
# 2  Afghanistan  Mohammad Shahzad  100.0     138.88  8-16-2010
# 3  Afghanistan  Mohammad Shahzad   82.0      75.92  7-10-2010
# 4  Afghanistan  Mohammad Shahzad   57.0     100.00   7-1-2010
#
#                   Ground       Versus  \
# 0     Sharjah CA Stadium       Canada
# 1             VRA Ground  Netherlands
# 2  Cambusdoon New Ground     Scotland
# 3            Hazelaarweg  Netherlands
# 4    Sportpark Westvliet       Canada
#
#                                                 URL
# 0  ../Matches/MatchScorecard_ODI.asp?MatchCode=3087
# 1  ../Matches/MatchScorecard_ODI.asp?MatchCode=3008
# 2  ../Matches/MatchScorecard_ODI.asp?MatchCode=3164
# 3  ../Matches/MatchScorecard_ODI.asp?MatchCode=3153
# 4  ../Matches/MatchScorecard_ODI.asp?MatchCode=3135

# %%
x.shape
# Out:
# (55926, 8)

# %%
x['Country'].value_counts()
x.isnull().sum()
# Out:
# Country       0
# Player        0
# Runs         26
# ScoreRate    26
# MatchDate     0
# Ground        0
# Versus        0
# URL           0
# dtype: int64

# %%
x['Runs'].value_counts().sum()
# Out:
# 55900

# %%
x.apply(lambda x:len(x.unique()))
# Out:
# Country        22
# Player       1936
# Runs          181
# ScoreRate    4197
# MatchDate    2757
# Ground        178
# Versus         25
# URL          3209
# dtype: int64

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55926 entries, 0 to 55925
# Data columns (total 8 columns):
# Country      55926 non-null object
# Player       55926 non-null object
# Runs         55900 non-null float64
# ScoreRate    55900 non-null float64
# MatchDate    55926 non-null object
# Ground       55926 non-null object
# Versus       55926 non-null object
# URL          55926 non-null object
# dtypes: float64(2), object(6)
# memory usage: 2.1+ MB

# %% [markdown]
# item_avg_weight=data.pivot_table(values='Item_Weight',index='Item_Identifier',aggfunc='first')
# #print(item_avg_weight)
# miss_bool=data['Item_Weight'].isnull()
# print ('Original missing:%d'%sum(miss_bool))
# data.loc[miss_bool,'Item_Weight'] = data.loc[miss_bool,'Item_Identifier'].apply(lambda x: item_avg_weight.at[x,'Item_Weight'])
# print('final missing:%d'% sum(data['Item_Weight'].isnull()))

# %%
run_avg=x.pivot_table(values='Runs',index='Player',aggfunc='first')
#print(playear_avg)

# %%
miss_bool=x['Runs'].isnull()
print('Original missing:%d'%sum(miss_bool))
x.loc[miss_bool,'Runs']=x.loc[miss_bool,'Player'].apply(lambda x:run_avg.at[x,'Runs'])
print(sum(x['Runs'].isnull()))
# Out:
# Original missing:26
# 0

# %%
run_avg=x.pivot_table(values='ScoreRate',index='Player',aggfunc='first')
#print(playear_avg)

# %%
miss_bool=x['ScoreRate'].isnull()
print('Original missing:%d'%sum(miss_bool))
x.loc[miss_bool,'ScoreRate']=x.loc[miss_bool,'Player'].apply(lambda x:run_avg.at[x,'ScoreRate'])
print(sum(x['ScoreRate'].isnull()))
# Out:
# Original missing:26
# 0

# %%
x.describe()
# Out:
#                Runs     ScoreRate
# count  55926.000000  55926.000000
# mean      22.267157     65.332467
# std       25.596119     44.219854
# min        0.000000      0.000000
# 25%        4.000000     37.500000
# 50%       13.000000     62.710000
# 75%       32.000000     87.500000
# max      200.000000    600.000000

# %%
x.isnull().sum()
# Out:
# Country      0
# Player       0
# Runs         0
# ScoreRate    0
# MatchDate    0
# Ground       0
# Versus       0
# URL          0
# dtype: int64

# %%
x.shape
# Out:
# (55926, 8)

# %%
x.ndim
# Out:
# 2

# %%
import seaborn as sns
#import matplotlib.pyplot as plt
#%matplotlib inline
#import math
import matplotlib.pyplot as plt
# %matplotlib inline
import math

# %%
x.head(1)
# Out:
#        Country            Player   Runs  ScoreRate  MatchDate  \
# 0  Afghanistan  Mohammad Shahzad  118.0      97.52  2-16-2010
#
#                Ground  Versus  \
# 0  Sharjah CA Stadium  Canada
#
#                                                 URL
# 0  ../Matches/MatchScorecard_ODI.asp?MatchCode=3087

# %%
plt.figure(figsize=(30,8))
sns.countplot(x='Country',data=x)

# %%
plt.figure(figsize=(30,8))
sns.countplot(x='Player',data=x)

# %%
plt.figure(figsize=(30,8))
sns.countplot(x='Runs',data=x)

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='ScoreRate',data=x)

# %%
plt.figure(figsize=(30,8))
sns.countplot(x='MatchDate',data=x)

# %%
#plt.figure(figsize=(12,8))

plt.figure(figsize=(30,8))
sns.countplot(x='Ground',data=x)

# %%
plt.figure(figsize=(30,8))
sns.countplot(x='Versus',data=x)

# %%
sns.countplot(x='URL',data=x)
